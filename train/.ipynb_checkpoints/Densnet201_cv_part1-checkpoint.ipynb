# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading https://files.pythonhosted.org/packages/e5/74/5d03afabe2d4c15387c12075d076992c23af28041910a9b73d87e5a27de1/gdown-3.5.0.tar.gz
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gdown) (2.18.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gdown) (4.25.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2018.8.24)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (3.0.4)
# Building wheels for collected packages: gdown
# done
#   Stored in directory: /root/.cache/pip/wheels/b0/e0/ea/f411b963cb7d0a6eeeee44d42ae328d415a71460baa3702459
# Successfully built gdown
# Installing collected packages: gdown
# Successfully installed gdown-3.5.0

# %%
import gdown

url = 'https://drive.google.com/uc?id=1ltHXdJBlYNZXNTugf5K4XtsDHsU_Rq5d'
output = 'data.zip'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ltHXdJBlYNZXNTugf5K4XtsDHsU_Rq5d
# To: /content/data.zip
# 6.71GB [00:51, 131MB/s]
# 'data.zip'

# %%
gdown.download('https://drive.google.com/uc?id=1pXGQ5VPnZG-qshA_WIIftrLv9xuLlTaX', 'test1.csv', quiet=True)
gdown.download('https://drive.google.com/uc?id=1Z3ICr_BhxlA0BuxGlIkwl1igoR-XExt9', 'test2.csv', quiet=True)
gdown.download('https://drive.google.com/uc?id=1mPdgZ3p_poe3VQDCwFQMFn_A1pGEHrO7', 'test3.csv', quiet=True)
gdown.download('https://drive.google.com/uc?id=1s7DytlooFsW9bxLgg7FLxlTS_D4YVT2j', 'test4.csv', quiet=True)
gdown.download('https://drive.google.com/uc?id=1U4xTkH3RvJMlSmmOEaeEkHTCscHwP-KO', 'test5.csv', quiet=True)
# Out:
# 'test5.csv'

# %%
# !unzip -qq data.zip

# %%
from skimage.io import imread, imshow, imsave
from skimage.transform import resize, rotate
import matplotlib.pyplot as plt
import numpy as np
import os
from __future__ import print_function
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping
import random
from sklearn.model_selection import train_test_split
import glob
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import shutil
# Out:
# Using TensorFlow backend.

# %%
path_train = 'data/IDRND_FASDB_train/'
path_val = 'data/IDRND_FASDB_val/'
path_test = 'data/test/'
BATCH_SIZE = 8
img_rows = 224
img_cols = 224
nb_classes = 2

# %%
# !mv  -v ./data/IDRND_FASDB_val/real/* ./data/IDRND_FASDB_train/real/
# !mv  -v ./data/IDRND_FASDB_val/spoof/* ./data/IDRND_FASDB_train/spoof/
# Out:
# './data/IDRND_FASDB_val/real/0004.png' -> './data/IDRND_FASDB_train/real/0004.png'
# './data/IDRND_FASDB_val/real/0007.png' -> './data/IDRND_FASDB_train/real/0007.png'
# './data/IDRND_FASDB_val/real/0023.png' -> './data/IDRND_FASDB_train/real/0023.png'
# './data/IDRND_FASDB_val/real/0028.png' -> './data/IDRND_FASDB_train/real/0028.png'
# './data/IDRND_FASDB_val/real/0029.png' -> './data/IDRND_FASDB_train/real/0029.png'
# './data/IDRND_FASDB_val/real/0034.png' -> './data/IDRND_FASDB_train/real/0034.png'
# './data/IDRND_FASDB_val/real/0035.png' -> './data/IDRND_FASDB_train/real/0035.png'
# './data/IDRND_FASDB_val/real/0044.png' -> './data/IDRND_FASDB_train/real/0044.png'
# './data/IDRND_FASDB_val/real/0047.png' -> './data/IDRND_FASDB_train/real/0047.png'
# './data/IDRND_FASDB_val/real/0049.png' -> './data/IDRND_FASDB_train/real/0049.png'
# './data/IDRND_FASDB_val/real/FT720P_id7_s0_45.png' -> './data/IDRND_FASDB_train/real/FT720P_id7_s0_45.png'
# './data/IDRND_FASDB_val/real/FT720P_id7_s0_60.png' -> './data/IDRND_FASDB_train/real/FT720P_id7_s0_60.png'
# './data/IDRND_FASDB_val/real/FT720P_id8_s0_75.png' -> './data/IDRND_FASDB_train/real/FT720P_id8_s0_75.png'
# './data/IDRND_FASDB_val/real/FT720P_id8_s1_45.png' -> './data/IDRND_FASDB_train/real/FT720P_id8_s1_45.png'
# './data/IDRND_FASDB_val/real/FT720P_id8_s1_60.png' -> './data/IDRND_FASDB_train/real/FT720P_id8_s1_60.png'
# './data/IDRND_FASDB_val/real/FT720P_id8_s1_90.png' -> './data/IDRND_FASDB_train/real/FT720P_id8_s1_90.png'
# './data/IDRND_FASDB_val/real/HTCD620_id117_s0_105.png' -> './data/IDRND_FASDB_train/real/HTCD620_id117_s0_105.png'
# './data/IDRND_FASDB_val/real/HTCD620_id117_s0_90.png' -> './data/IDRND_FASDB_train/real/HTCD620_id117_s0_90.png'
# './data/IDRND_FASDB_val/real/HUAWEIP7L_id122_s0_105.png' -> './data/IDRND_FASDB_train/real/HUAWEIP7L_id122_s0_105.png'
# './data/IDRND_FASDB_val/real/IPHONE8B_id3_s2_135.png' -> './data/IDRND_FASDB_train/real/IPHONE8B_id3_s2_135.png'
# './data/IDRND_FASDB_val/real/IPHONE8B_id3_s2_30.png' -> './data/IDRND_FASDB_train/real/IPHONE8B_id3_s2_30.png'
# './data/IDRND_FASDB_val/real/IPHONE8B_id4_s2_15.png' -> './data/IDRND_FASDB_train/real/IPHONE8B_id4_s2_15.png'
# './data/IDRND_FASDB_val/real/IPHONE8B_id4_s2_60.png' -> './data/IDRND_FASDB_train/real/IPHONE8B_id4_s2_60.png'
# './data/IDRND_FASDB_val/real/IPHONE8B_id7_s2_135.png' -> './data/IDRND_FASDB_train/real/IPHONE8B_id7_s2_135.png'
# './data/IDRND_FASDB_val/real/LTC270_id144_s0_109.png' -> './data/IDRND_FASDB_train/real/LTC270_id144_s0_109.png'
# './data/IDRND_FASDB_val/real/LTC270_id144_s0_124.png' -> './data/IDRND_FASDB_train/real/LTC270_id144_s0_124.png'
# './data/IDRND_FASDB_val/real/LTC270_id144_s0_139.png' -> './data/IDRND_FASDB_train/real/LTC270_id144_s0_139.png'
# './data/IDRND_FASDB_val/real/LTC270_id144_s0_30.png' -> './data/IDRND_FASDB_train/real/LTC270_id144_s0_30.png'
# './data/IDRND_FASDB_val/real/LTC270_id151_s0_103.png' -> './data/IDRND_FASDB_train/real/LTC270_id151_s0_103.png'
# './data/IDRND_FASDB_val/real/LTC270_id151_s0_118.png' -> './data/IDRND_FASDB_train/real/LTC270_id151_s0_118.png'
# './data/IDRND_FASDB_val/real/LTC270_id151_s0_88.png' -> './data/IDRND_FASDB_train/real/LTC270_id151_s0_88.png'
# './data/IDRND_FASDB_val/real/PBENTE11HC_id153_s0_15.png' -> './data/IDRND_FASDB_train/real/PBENTE11HC_id153_s0_15.png'
# './data/IDRND_FASDB_val/spoof/0038.png' -> './data/IDRND_FASDB_train/spoof/0038.png'
# './data/IDRND_FASDB_val/spoof/0043.png' -> './data/IDRND_FASDB_train/spoof/0043.png'
# './data/IDRND_FASDB_val/spoof/0062.png' -> './data/IDRND_FASDB_train/spoof/0062.png'
# './data/IDRND_FASDB_val/spoof/0063.png' -> './data/IDRND_FASDB_train/spoof/0063.png'
# './data/IDRND_FASDB_val/spoof/0065.png' -> './data/IDRND_FASDB_train/spoof/0065.png'
# './data/IDRND_FASDB_val/spoof/0072.png' -> './data/IDRND_FASDB_train/spoof/0072.png'
# './data/IDRND_FASDB_val/spoof/0073.png' -> './data/IDRND_FASDB_train/spoof/0073.png'
# './data/IDRND_FASDB_val/spoof/0075.png' -> './data/IDRND_FASDB_train/spoof/0075.png'
# './data/IDRND_FASDB_val/spoof/0079.png' -> './data/IDRND_FASDB_train/spoof/0079.png'
# './data/IDRND_FASDB_val/spoof/0081.png' -> './data/IDRND_FASDB_train/spoof/0081.png'
# './data/IDRND_FASDB_val/spoof/0083.png' -> './data/IDRND_FASDB_train/spoof/0083.png'
# './data/IDRND_FASDB_val/spoof/0097.png' -> './data/IDRND_FASDB_train/spoof/0097.png'
# './data/IDRND_FASDB_val/spoof/0098.png' -> './data/IDRND_FASDB_train/spoof/0098.png'
# './data/IDRND_FASDB_val/spoof/0120.png' -> './data/IDRND_FASDB_train/spoof/0120.png'
# './data/IDRND_FASDB_val/spoof/0147.png' -> './data/IDRND_FASDB_train/spoof/0147.png'
# './data/IDRND_FASDB_val/spoof/0151.png' -> './data/IDRND_FASDB_train/spoof/0151.png'
# './data/IDRND_FASDB_val/spoof/0152.png' -> './data/IDRND_FASDB_train/spoof/0152.png'
# './data/IDRND_FASDB_val/spoof/0153.png' -> './data/IDRND_FASDB_train/spoof/0153.png'
# './data/IDRND_FASDB_val/spoof/0161.png' -> './data/IDRND_FASDB_train/spoof/0161.png'
# './data/IDRND_FASDB_val/spoof/0162.png' -> './data/IDRND_FASDB_train/spoof/0162.png'
# './data/IDRND_FASDB_val/spoof/0164.png' -> './data/IDRND_FASDB_train/spoof/0164.png'
# './data/IDRND_FASDB_val/spoof/0183.png' -> './data/IDRND_FASDB_train/spoof/0183.png'
# './data/IDRND_FASDB_val/spoof/0194.png' -> './data/IDRND_FASDB_train/spoof/0194.png'
# './data/IDRND_FASDB_val/spoof/0201.png' -> './data/IDRND_FASDB_train/spoof/0201.png'
# './data/IDRND_FASDB_val/spoof/0202.png' -> './data/IDRND_FASDB_train/spoof/0202.png'
# './data/IDRND_FASDB_val/spoof/0204.png' -> './data/IDRND_FASDB_train/spoof/0204.png'
# './data/IDRND_FASDB_val/spoof/0217.png' -> './data/IDRND_FASDB_train/spoof/0217.png'
# './data/IDRND_FASDB_val/spoof/0223.png' -> './data/IDRND_FASDB_train/spoof/0223.png'
# './data/IDRND_FASDB_val/spoof/0224.png' -> './data/IDRND_FASDB_train/spoof/0224.png'
# './data/IDRND_FASDB_val/spoof/0227.png' -> './data/IDRND_FASDB_train/spoof/0227.png'
# './data/IDRND_FASDB_val/spoof/0232.png' -> './data/IDRND_FASDB_train/spoof/0232.png'
# './data/IDRND_FASDB_val/spoof/0241.png' -> './data/IDRND_FASDB_train/spoof/0241.png'
# './data/IDRND_FASDB_val/spoof/0249.png' -> './data/IDRND_FASDB_train/spoof/0249.png'
# './data/IDRND_FASDB_val/spoof/0257.png' -> './data/IDRND_FASDB_train/spoof/0257.png'
# './data/IDRND_FASDB_val/spoof/0278.png' -> './data/IDRND_FASDB_train/spoof/0278.png'
# './data/IDRND_FASDB_val/spoof/0279.png' -> './data/IDRND_FASDB_train/spoof/0279.png'
# './data/IDRND_FASDB_val/spoof/0281.png' -> './data/IDRND_FASDB_train/spoof/0281.png'
# './data/IDRND_FASDB_val/spoof/0286.png' -> './data/IDRND_FASDB_train/spoof/0286.png'
# './data/IDRND_FASDB_val/spoof/0294.png' -> './data/IDRND_FASDB_train/spoof/0294.png'
# './data/IDRND_FASDB_val/spoof/0299.png' -> './data/IDRND_FASDB_train/spoof/0299.png'
# './data/IDRND_FASDB_val/spoof/0304.png' -> './data/IDRND_FASDB_train/spoof/0304.png'
# './data/IDRND_FASDB_val/spoof/0310.png' -> './data/IDRND_FASDB_train/spoof/0310.png'
# './data/IDRND_FASDB_val/spoof/0311.png' -> './data/IDRND_FASDB_train/spoof/0311.png'
# './data/IDRND_FASDB_val/spoof/0313.png' -> './data/IDRND_FASDB_train/spoof/0313.png'
# './data/IDRND_FASDB_val/spoof/0318.png' -> './data/IDRND_FASDB_train/spoof/0318.png'
# './data/IDRND_FASDB_val/spoof/0322.png' -> './data/IDRND_FASDB_train/spoof/0322.png'
# './data/IDRND_FASDB_val/spoof/0323.png' -> './data/IDRND_FASDB_train/spoof/0323.png'
# './data/IDRND_FASDB_val/spoof/0324.png' -> './data/IDRND_FASDB_train/spoof/0324.png'
# './data/IDRND_FASDB_val/spoof/0325.png' -> './data/IDRND_FASDB_train/spoof/0325.png'
# './data/IDRND_FASDB_val/spoof/0328.png' -> './data/IDRND_FASDB_train/spoof/0328.png'
# './data/IDRND_FASDB_val/spoof/0332.png' -> './data/IDRND_FASDB_train/spoof/0332.png'
# './data/IDRND_FASDB_val/spoof/0341.png' -> './data/IDRND_FASDB_train/spoof/0341.png'
# './data/IDRND_FASDB_val/spoof/0342.png' -> './data/IDRND_FASDB_train/spoof/0342.png'
# './data/IDRND_FASDB_val/spoof/0346.png' -> './data/IDRND_FASDB_train/spoof/0346.png'
# './data/IDRND_FASDB_val/spoof/0352.png' -> './data/IDRND_FASDB_train/spoof/0352.png'
# './data/IDRND_FASDB_val/spoof/0361.png' -> './data/IDRND_FASDB_train/spoof/0361.png'
# './data/IDRND_FASDB_val/spoof/0363.png' -> './data/IDRND_FASDB_train/spoof/0363.png'
# './data/IDRND_FASDB_val/spoof/0364.png' -> './data/IDRND_FASDB_train/spoof/0364.png'
# './data/IDRND_FASDB_val/spoof/0367.png' -> './data/IDRND_FASDB_train/spoof/0367.png'
# './data/IDRND_FASDB_val/spoof/0368.png' -> './data/IDRND_FASDB_train/spoof/0368.png'
# './data/IDRND_FASDB_val/spoof/0369.png' -> './data/IDRND_FASDB_train/spoof/0369.png'
# './data/IDRND_FASDB_val/spoof/0370.png' -> './data/IDRND_FASDB_train/spoof/0370.png'
# './data/IDRND_FASDB_val/spoof/0380.png' -> './data/IDRND_FASDB_train/spoof/0380.png'
# './data/IDRND_FASDB_val/spoof/0382.png' -> './data/IDRND_FASDB_train/spoof/0382.png'
# './data/IDRND_FASDB_val/spoof/0383.png' -> './data/IDRND_FASDB_train/spoof/0383.png'
# './data/IDRND_FASDB_val/spoof/0387.png' -> './data/IDRND_FASDB_train/spoof/0387.png'
# './data/IDRND_FASDB_val/spoof/0388.png' -> './data/IDRND_FASDB_train/spoof/0388.png'
# './data/IDRND_FASDB_val/spoof/0406.png' -> './data/IDRND_FASDB_train/spoof/0406.png'
# './data/IDRND_FASDB_val/spoof/0415.png' -> './data/IDRND_FASDB_train/spoof/0415.png'
# './data/IDRND_FASDB_val/spoof/0418.png' -> './data/IDRND_FASDB_train/spoof/0418.png'
# './data/IDRND_FASDB_val/spoof/0421.png' -> './data/IDRND_FASDB_train/spoof/0421.png'
# './data/IDRND_FASDB_val/spoof/0424.png' -> './data/IDRND_FASDB_train/spoof/0424.png'
# './data/IDRND_FASDB_val/spoof/0425.png' -> './data/IDRND_FASDB_train/spoof/0425.png'
# './data/IDRND_FASDB_val/spoof/0438.png' -> './data/IDRND_FASDB_train/spoof/0438.png'
# './data/IDRND_FASDB_val/spoof/0441.png' -> './data/IDRND_FASDB_train/spoof/0441.png'
# './data/IDRND_FASDB_val/spoof/0443.png' -> './data/IDRND_FASDB_train/spoof/0443.png'
# './data/IDRND_FASDB_val/spoof/0444.png' -> './data/IDRND_FASDB_train/spoof/0444.png'
# './data/IDRND_FASDB_val/spoof/0449.png' -> './data/IDRND_FASDB_train/spoof/0449.png'
# './data/IDRND_FASDB_val/spoof/0451.png' -> './data/IDRND_FASDB_train/spoof/0451.png'
# './data/IDRND_FASDB_val/spoof/0458.png' -> './data/IDRND_FASDB_train/spoof/0458.png'
# './data/IDRND_FASDB_val/spoof/0459.png' -> './data/IDRND_FASDB_train/spoof/0459.png'
# './data/IDRND_FASDB_val/spoof/0460.png' -> './data/IDRND_FASDB_train/spoof/0460.png'
# './data/IDRND_FASDB_val/spoof/0465.png' -> './data/IDRND_FASDB_train/spoof/0465.png'
# './data/IDRND_FASDB_val/spoof/0468.png' -> './data/IDRND_FASDB_train/spoof/0468.png'
# './data/IDRND_FASDB_val/spoof/0472.png' -> './data/IDRND_FASDB_train/spoof/0472.png'
# './data/IDRND_FASDB_val/spoof/0476.png' -> './data/IDRND_FASDB_train/spoof/0476.png'
# './data/IDRND_FASDB_val/spoof/0480.png' -> './data/IDRND_FASDB_train/spoof/0480.png'
# './data/IDRND_FASDB_val/spoof/0492.png' -> './data/IDRND_FASDB_train/spoof/0492.png'
# './data/IDRND_FASDB_val/spoof/0493.png' -> './data/IDRND_FASDB_train/spoof/0493.png'
# './data/IDRND_FASDB_val/spoof/0494.png' -> './data/IDRND_FASDB_train/spoof/0494.png'
# './data/IDRND_FASDB_val/spoof/0496.png' -> './data/IDRND_FASDB_train/spoof/0496.png'
# './data/IDRND_FASDB_val/spoof/0499.png' -> './data/IDRND_FASDB_train/spoof/0499.png'
# './data/IDRND_FASDB_val/spoof/0500.png' -> './data/IDRND_FASDB_train/spoof/0500.png'
# './data/IDRND_FASDB_val/spoof/0510.png' -> './data/IDRND_FASDB_train/spoof/0510.png'
# './data/IDRND_FASDB_val/spoof/0514.png' -> './data/IDRND_FASDB_train/spoof/0514.png'
# './data/IDRND_FASDB_val/spoof/0515.png' -> './data/IDRND_FASDB_train/spoof/0515.png'
# './data/IDRND_FASDB_val/spoof/0525.png' -> './data/IDRND_FASDB_train/spoof/0525.png'
# './data/IDRND_FASDB_val/spoof/0530.png' -> './data/IDRND_FASDB_train/spoof/0530.png'
# './data/IDRND_FASDB_val/spoof/0541.png' -> './data/IDRND_FASDB_train/spoof/0541.png'
# './data/IDRND_FASDB_val/spoof/0542.png' -> './data/IDRND_FASDB_train/spoof/0542.png'
# './data/IDRND_FASDB_val/spoof/0557.png' -> './data/IDRND_FASDB_train/spoof/0557.png'
# './data/IDRND_FASDB_val/spoof/0562.png' -> './data/IDRND_FASDB_train/spoof/0562.png'
# './data/IDRND_FASDB_val/spoof/0570.png' -> './data/IDRND_FASDB_train/spoof/0570.png'
# './data/IDRND_FASDB_val/spoof/0575.png' -> './data/IDRND_FASDB_train/spoof/0575.png'
# './data/IDRND_FASDB_val/spoof/0577.png' -> './data/IDRND_FASDB_train/spoof/0577.png'
# './data/IDRND_FASDB_val/spoof/0580.png' -> './data/IDRND_FASDB_train/spoof/0580.png'
# './data/IDRND_FASDB_val/spoof/0581.png' -> './data/IDRND_FASDB_train/spoof/0581.png'
# './data/IDRND_FASDB_val/spoof/0586.png' -> './data/IDRND_FASDB_train/spoof/0586.png'
# './data/IDRND_FASDB_val/spoof/0587.png' -> './data/IDRND_FASDB_train/spoof/0587.png'
# './data/IDRND_FASDB_val/spoof/0591.png' -> './data/IDRND_FASDB_train/spoof/0591.png'
# './data/IDRND_FASDB_val/spoof/0592.png' -> './data/IDRND_FASDB_train/spoof/0592.png'
# './data/IDRND_FASDB_val/spoof/0595.png' -> './data/IDRND_FASDB_train/spoof/0595.png'
# './data/IDRND_FASDB_val/spoof/0598.png' -> './data/IDRND_FASDB_train/spoof/0598.png'
# './data/IDRND_FASDB_val/spoof/0608.png' -> './data/IDRND_FASDB_train/spoof/0608.png'
# './data/IDRND_FASDB_val/spoof/0610.png' -> './data/IDRND_FASDB_train/spoof/0610.png'
# './data/IDRND_FASDB_val/spoof/0614.png' -> './data/IDRND_FASDB_train/spoof/0614.png'
# './data/IDRND_FASDB_val/spoof/0617.png' -> './data/IDRND_FASDB_train/spoof/0617.png'
# './data/IDRND_FASDB_val/spoof/0619.png' -> './data/IDRND_FASDB_train/spoof/0619.png'
# './data/IDRND_FASDB_val/spoof/FT720P_G780_REDMI4X_
60.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TP300LA_SGS7E_id41_s1_60.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TP300LA_SGS7E_id47_s1_105.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TP300LA_SGS7E_id47_s1_105.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TP300LA_SGS7E_id47_s1_15.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TP300LA_SGS7E_id47_s1_15.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TP300LA_SGS7E_id47_s1_60.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TP300LA_SGS7E_id47_s1_60.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S0_id36_s0_15.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S0_id36_s0_15.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S0_id36_s0_78.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S0_id36_s0_78.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S0_id36_s0_93.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S0_id36_s0_93.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S0_id59_s0_120.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S0_id59_s0_120.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id34_s0_155.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id34_s0_155.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id34_s0_185.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id34_s0_185.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id34_s0_200.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id34_s0_200.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id34_s0_215.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id34_s0_215.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id36_s0_15.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id36_s0_15.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id36_s0_93.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id36_s0_93.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id59_s0_105.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSLCD1510_LGK350EK8_S1_id59_s0_105.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id33_s1_105.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id33_s1_105.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id33_s1_150.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id33_s1_150.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id44_s0_105.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id44_s0_105.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id44_s0_75.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id44_s0_75.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s0_105.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s0_105.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s0_60.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s0_60.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s2_105.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s2_105.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s2_150.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s2_150.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s3_75.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id47_s3_75.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id56_s0_141.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id56_s0_141.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id56_s0_156.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id56_s0_156.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id56_s0_84.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id56_s0_84.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id57_s1_15.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id57_s1_15.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id57_s1_241.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_TSUNKNOWN_SGJ5_id57_s1_241.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id31_s0_151.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id31_s0_151.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id31_s0_30.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id31_s0_30.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id34_s0_199.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id34_s0_199.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id34_s0_214.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id34_s0_214.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id36_s0_101.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id36_s0_101.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id36_s0_120.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSUNKNOWN_REDMIN5A_id36_s0_120.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id31_s0_92.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id31_s0_92.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id34_s0_173.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id34_s0_173.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id36_s0_162.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id36_s0_162.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id36_s0_30.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id36_s0_30.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id59_s0_30.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id59_s0_30.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id59_s0_60.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VSVA2231WA_MEIZUM3S_id59_s0_60.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id33_s1_15.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id33_s1_15.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id33_s1_75.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id33_s1_75.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id41_s1_30.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id41_s1_30.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id41_s1_60.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id41_s1_60.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s0_15.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s0_15.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s0_60.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s0_60.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s1_135.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s1_135.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s2_105.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s2_105.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s2_135.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id47_s2_135.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id56_s0_106.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id56_s0_106.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id56_s0_136.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id56_s0_136.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id56_s0_45.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id56_s0_45.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id57_s0_135.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id57_s0_135.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id57_s0_90.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id57_s0_90.png'
# './data/IDRND_FASDB_val/spoof/YOUTUBE_VX2363SMHL_LGL90_id57_s1_45.png' -> './data/IDRND_FASDB_train/spoof/YOUTUBE_VX2363SMHL_LGL90_id57_s1_45.png'

# %%
train_real_filelist = glob.glob(os.path.join(path_train, 'real/*.png'))
train_spoof_filelist = glob.glob(os.path.join(path_train, 'spoof/*.png'))
train_filelist = train_real_filelist + train_spoof_filelist
train_labels = [0] * len(train_real_filelist) + [1] * len(train_spoof_filelist)
train = pd.DataFrame()
train['path'] = train_filelist
train['label'] = train_labels

test_filelist = glob.glob(os.path.join(path_test, '*.png'))
test = pd.DataFrame()
test['path'] = test_filelist

# %%
# skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
# X_train_cv = skf.split(train['path'].values, train['label'].values)

# index_train_dict = {}
# index_test_dict = {}
# for i in range(5):
#   ind = next(X_train_cv)
#   index_train_dict['split_{}'.format(i)] = ind[0]
#   index_test_dict['split_{}'.format(i)] = ind[1]

# train['path'][index_test_dict['split_0']].to_csv('test1.csv')
# train['path'][index_test_dict['split_1']].to_csv('test2.csv')
# train['path'][index_test_dict['split_2']].to_csv('test3.csv')
# train['path'][index_test_dict['split_3']].to_csv('test4.csv')
# train['path'][index_test_dict['split_4']].to_csv('test5.csv')

# %%
#read index
val_id = pd.read_csv('test5.csv', index_col = None, header=None)
val_id.columns = ['id', 'path']
val_id.head()
# Out:
#    id                                               path
# 0   1  data/IDRND_FASDB_train/real/YOUTUBE_id97_s0_34...
# 1  22  data/IDRND_FASDB_train/real/YOUTUBE_id100_s0_7...
# 2  30  data/IDRND_FASDB_train/real/YOUTUBE_id75_s0_19...
# 3  31               data/IDRND_FASDB_train/real/0277.png
# 4  32               data/IDRND_FASDB_train/real/0049.png

# %%
#move files
for path in val_id['path']:
  shutil.move(path, path.replace('IDRND_FASDB_train','IDRND_FASDB_val'))

# %%
train_real_filelist = glob.glob(os.path.join(path_train, 'real/*.png'))
train_spoof_filelist = glob.glob(os.path.join(path_train, 'spoof/*.png'))
train_filelist = train_real_filelist + train_spoof_filelist
train_labels = [0] * len(train_real_filelist) + [1] * len(train_spoof_filelist)
train = pd.DataFrame()
train['path'] = train_filelist
train['label'] = train_labels

val_real_filelist = glob.glob(os.path.join(path_val, 'real/*.png'))
val_spoof_filelist = glob.glob(os.path.join(path_val, 'spoof/*.png'))
val_filelist = val_real_filelist + val_spoof_filelist
val_labels = [0] * len(val_real_filelist) + [1] * len(val_spoof_filelist)
val = pd.DataFrame()
val['path'] = val_filelist
val['label'] = val_labels

# %%
from keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode = 'nearest')

test_datagen = ImageDataGenerator(rescale=1./255, fill_mode = 'nearest')

train_gen = train_gen.flow_from_directory(
        path_train,
        target_size=(img_rows, img_rows),
        batch_size=BATCH_SIZE,
        class_mode='binary')

val_gen = test_datagen.flow_from_directory(
        path_val,
        target_size=(img_rows, img_rows),
        batch_size=BATCH_SIZE,
        class_mode='binary')
# Out:
# Found 7444 images belonging to 2 classes.
# Found 1860 images belonging to 2 classes.

# %% [markdown]
# # Build Model

# %%
from keras.applications import DenseNet201
model = DenseNet201(weights = "imagenet", include_top=False, input_shape = (img_rows, img_cols, 3))

# freeze layers
# for layer in model.layers[:5]:
#     layer.trainable = False

from keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.regularizers import l2
#Adding custom Layers 
x = model.output
x = Flatten()(x)
x = Dense(2048, activation="elu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
# x = Dropout(0.5)(x)
x = Dense(1024, activation="elu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
# x = Dropout(0.5)(x)
predictions = Dense(1, activation="sigmoid", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)

from keras.models import Model
# creating the final model 
model_final = Model(input = model.input, output = predictions)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.8/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 76398592/76391848 [==============================] - 16s 0us/step
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`

# %%
from keras.optimizers import Adam
from sklearn.metrics import roc_curve, auc, roc_auc_score
from keras.models import Model

from keras import backend as K
import tensorflow as tf
def auc(y_true, y_pred):
    auc = tf.metrics.auc(y_true, y_pred)[1]
    K.get_session().run(tf.local_variables_initializer())
    return auc
  
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# compile the model 
model_final.compile(loss = "binary_crossentropy", optimizer = Adam(lr=0.0001, decay=0.0001), metrics=['accuracy',auc,f1])

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from google.colab import files

weight_path='DensNet201_part3.h5'

checkpoint = ModelCheckpoint(weight_path, monitor='val_auc', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only=False)

reduceLROnPlat = ReduceLROnPlateau(monitor='f1', factor=0.1, patience=3, 
                                   verbose=1, mode='max', min_lr=0.0000001)

def exp_decay(epoch):
  initial_lrate = 0.0001
  k = 0.1
  lrate = initial_lrate * np.exp(-k*epoch)
  return lrate
lrate = LearningRateScheduler(exp_decay)
  
# class SaveWeight(Callback):
#     def on_epoch_end(self, batch, logs={}):
#         files.download('ResNet101_weights.hdf5')
#         return

# save_weight = SaveWeight()

callbacks_list = [checkpoint, lrate]

# %%
lr = [exp_decay(i) for i in range(30)]
plt.plot(lr)

# %%
loss_history = [model_final.fit_generator(train_gen, 
                             steps_per_epoch = 7440/BATCH_SIZE, 
                             epochs = 35,
                             validation_data = val_gen,
                             validation_steps = 1800/BATCH_SIZE,
                             callbacks = callbacks_list)]
# Out:
# WARNING:tensorflow:Variable *= will be deprecated. Use `var.assign(var * other)` if you want assignment to the variable value or `x = x * y` if you want a new python Tensor object.
# Epoch 1/35
# 930/930 [==============================] - 1068s 1s/step - loss: 0.7928 - acc: 0.8530 - auc: 0.8338 - f1: 0.9013 - val_loss: 0.6173 - val_acc: 0.8806 - val_auc: 0.8938 - val_f1: 0.9277
#
# Epoch 00001: val_auc improved from -inf to 0.89379, saving model to DensNet201_part3.h5
# Epoch 2/35
# 930/930 [==============================] - 984s 1s/step - loss: 0.4850 - acc: 0.9513 - auc: 0.9133 - f1: 0.9688 - val_loss: 0.3863 - val_acc: 0.9861 - val_auc: 0.9360 - val_f1: 0.9907
#
# Epoch 00002: val_auc improved from 0.89379 to 0.93596, saving model to DensNet201_part3.h5
# Epoch 3/35
# 930/930 [==============================] - 984s 1s/step - loss: 0.4202 - acc: 0.9679 - auc: 0.9488 - f1: 0.9786 - val_loss: 0.3985 - val_acc: 0.9750 - val_auc: 0.9575 - val_f1: 0.9842
#
# Epoch 00003: val_auc improved from 0.93596 to 0.95750, saving model to DensNet201_part3.h5
# Epoch 4/35
# 930/930 [==============================] - 981s 1s/step - loss: 0.3762 - acc: 0.9761 - auc: 0.9638 - f1: 0.9842 - val_loss: 0.3270 - val_acc: 0.9911 - val_auc: 0.9692 - val_f1: 0.9944
#
# Epoch 00004: val_auc improved from 0.95750 to 0.96924, saving model to DensNet201_part3.h5
# Epoch 5/35
# 930/930 [==============================] - 979s 1s/step - loss: 0.3456 - acc: 0.9820 - auc: 0.9733 - f1: 0.9879 - val_loss: 0.3002 - val_acc: 0.9989 - val_auc: 0.9768 - val_f1: 0.9992
#
# Epoch 00005: val_auc improved from 0.96924 to 0.97677, saving model to DensNet201_part3.h5
# Epoch 6/35
# 930/930 [==============================] - 972s 1s/step - loss: 0.3228 - acc: 0.9836 - auc: 0.9793 - f1: 0.9888 - val_loss: 0.2925 - val_acc: 0.9939 - val_auc: 0.9813 - val_f1: 0.9959
#
# Epoch 00006: val_auc improved from 0.97677 to 0.98130, saving model to DensNet201_part3.h5
# Epoch 7/35
# 930/930 [==============================] - 974s 1s/step - loss: 0.2924 - acc: 0.9880 - auc: 0.9830 - f1: 0.9918 - val_loss: 0.2619 - val_acc: 0.9967 - val_auc: 0.9846 - val_f1: 0.9978
#
# Epoch 00007: val_auc improved from 0.98130 to 0.98458, saving model to DensNet201_part3.h5
# Epoch 8/35
# 930/930 [==============================] - 978s 1s/step - loss: 0.2703 - acc: 0.9910 - auc: 0.9859 - f1: 0.9935 - val_loss: 0.2512 - val_acc: 0.9967 - val_auc: 0.9870 - val_f1: 0.9981
#
# Epoch 00008: val_auc improved from 0.98458 to 0.98702, saving model to DensNet201_part3.h5
# Epoch 9/35
# 930/930 [==============================] - 975s 1s/step - loss: 0.2451 - acc: 0.9934 - auc: 0.9880 - f1: 0.9952 - val_loss: 0.2208 - val_acc: 0.9983 - val_auc: 0.9890 - val_f1: 0.9990
#
# Epoch 00009: val_auc improved from 0.98702 to 0.98898, saving model to DensNet201_part3.h5
# Epoch 10/35
# 930/930 [==============================] - 973s 1s/step - loss: 0.2214 - acc: 0.9950 - auc: 0.9898 - f1: 0.9966 - val_loss: 0.2033 - val_acc: 0.9972 - val_auc: 0.9906 - val_f1: 0.9977
#
# Epoch 00010: val_auc improved from 0.98898 to 0.99059, saving model to DensNet201_part3.h5
# Epoch 11/35
# 930/930 [==============================] - 976s 1s/step - loss: 0.2016 - acc: 0.9964 - auc: 0.9913 - f1: 0.9973 - val_loss: 0.1966 - val_acc: 0.9967 - val_auc: 0.9919 - val_f1: 0.9980
#
# Epoch 00011: val_auc improved from 0.99059 to 0.99189, saving model to DensNet201_part3.h5
# Epoch 12/35
# 930/930 [==============================] - 974s 1s/step - loss: 0.1903 - acc: 0.9957 - auc: 0.9924 - f1: 0.9970 - val_loss: 0.1819 - val_acc: 0.9967 - val_auc: 0.9928 - val_f1: 0.9979
#
# Epoch 00012: val_auc improved from 0.99189 to 0.99285, saving model to DensNet201_part3.h5
# Epoch 13/35
# 930/930 [==============================] - 982s 1s/step - loss: 0.1754 - acc: 0.9969 - auc: 0.9933 - f1: 0.9978 - val_loss: 0.1637 - val_acc: 0.9994 - val_auc: 0.9937 - val_f1: 0.9997
#
# Epoch 00013: val_auc improved from 0.99285 to 0.99371, saving model to DensNet201_part3.h5
# Epoch 14/35
# 930/930 [==============================] - 979s 1s/step - loss: 0.1664 - acc: 0.9973 - auc: 0.9941 - f1: 0.9980 - val_loss: 0.1562 - val_acc: 0.9994 - val_auc: 0.9944 - val_f1: 0.9997
#
# Epoch 00014: val_auc improved from 0.99371 to 0.99439, saving model to DensNet201_part3.h5
# Epoch 15/35
# 930/930 [==============================] - 982s 1s/step - loss: 0.1518 - acc: 0.9991 - auc: 0.9947 - f1: 0.9994 - val_loss: 0.1451 - val_acc: 1.0000 - val_auc: 0.9950 - val_f1: 1.0000
#
# Epoch 00015: val_auc improved from 0.99439 to 0.99501, saving model to DensNet201_part3.h5
# Epoch 16/35
# 930/930 [==============================] - 981s 1s/step - loss: 0.1447 - acc: 0.9988 - auc: 0.9953 - f1: 0.9990 - val_loss: 0.1386 - val_acc: 0.9994 - val_auc: 0.9955 - val_f1: 0.9997
#
# Epoch 00016: val_auc improved from 0.99501 to 0.99551, saving model to DensNet201_part3.h5
# Epoch 17/35
# 930/930 [==============================] - 979s 1s/step - loss: 0.1375 - acc: 0.9988 - auc: 0.9957 - f1: 0.9991 - val_loss: 0.1303 - val_acc: 1.0000 - val_auc: 0.9959 - val_f1: 1.0000
#
# Epoch 00017: val_auc improved from 0.99551 to 0.99594, saving model to DensNet201_part3.h5
# Epoch 18/35
# 930/930 [==============================] - 980s 1s/step - loss: 0.1301 - acc: 0.9995 - auc: 0.9961 - f1: 0.9996 - val_loss: 0.1270 - val_acc: 1.0000 - val_auc: 0.9963 - val_f1: 1.0000
#
# Epoch 00018: val_auc improved from 0.99594 to 0.99632, saving model to DensNet201_part3.h5
# Epoch 19/35
# 930/930 [==============================] - 981s 1s/step - loss: 0.1238 - acc: 0.9995 - auc: 0.9965 - f1: 0.9995 - val_loss: 0.1241 - val_acc: 0.9989 - val_auc: 0.9966 - val_f1: 0.9993
#
# Epoch 00019: val_auc improved from 0.99632 to 0.99664, saving model to DensNet201_part3.h5
# Epoch 20/35
# 930/930 [==============================] - 982s 1s/step - loss: 0.1196 - acc: 0.9996 - auc: 0.9968 - f1: 0.9998 - val_loss: 0.1166 - val_acc: 0.9994 - val_auc: 0.9969 - val_f1: 0.9997
#
# Epoch 00020: val_auc improved from 0.99664 to 0.99692, saving model to DensNet201_part3.h5
# Epoch 21/35
# 930/930 [==============================] - 984s 1s/step - loss: 0.1156 - acc: 0.9991 - auc: 0.9970 - f1: 0.9993 - val_loss: 0.1143 - val_acc: 0.9994 - val_auc: 0.9972 - val_f1: 0.9997
#
# Epoch 00021: val_auc improved from 0.99692 to 0.99716, saving model to DensNet201_part3.h5
# Epoch 22/35
# 930/930 [==============================] - 981s 1s/step - loss: 0.1123 - acc: 0.9992 - auc: 0.9973 - f1: 0.9991 - val_loss: 0.1115 - val_acc: 0.9994 - val_auc: 0.9974 - val_f1: 0.9997
#
# Epoch 00022: val_auc improved from 0.99716 to 0.99737, saving model to DensNet201_part3.h5
# Epoch 23/35
# 930/930 [==============================] - 983s 1s/step - loss: 0.1089 - acc: 0.9996 - auc: 0.9975 - f1: 0.9996 - val_loss: 0.1075 - val_acc: 1.0000 - val_auc: 0.9976 - val_f1: 1.0000
#
# Epoch 00023: val_auc improved from 0.99737 to 0.99756, saving model to DensNet201_part3.h5
# Epoch 24/35
# 930/930 [==============================] - 979s 1s/step - loss: 0.1090 - acc: 0.9992 - auc: 0.9976 - f1: 0.9991 - val_loss: 0.1044 - val_acc: 1.0000 - val_auc: 0.9977 - val_f1: 1.0000
#
# Epoch 00024: val_auc improved from 0.99756 to 0.99769, saving model to DensNet201_part3.h5
# Epoch 25/35
# 930/930 [==============================] - 977s 1s/step - loss: 0.1048 - acc: 0.9997 - auc: 0.9978 - f1: 0.9998 - val_loss: 0.1033 - val_acc: 1.0000 - val_auc: 0.9978 - val_f1: 1.0000
#
# Epoch 00025: val_auc improved from 0.99769 to 0.99785, saving model to DensNet201_part3.h5
# Epoch 26/35
# 930/930 [==============================] - 974s 1s/step - loss: 0.1030 - acc: 0.9995 - auc: 0.9979 - f1: 0.9997 - val_loss: 0.1015 - val_acc: 1.0000 - val_auc: 0.9980 - val_f1: 1.0000
#
# Epoch 00026: val_auc improved from 0.99785 to 0.99798, saving model to DensNet201_part3.h5
# Epoch 27/35
# 930/930 [==============================] - 979s 1s/step - loss: 0.1017 - acc: 0.9995 - auc: 0.9980 - f1: 0.9997 - val_loss: 0.0994 - val_acc: 1.0000 - val_auc: 0.9981 - val_f1: 1.0000
#
# Epoch 00027: val_auc improved from 0.99798 to 0.99810, saving model to DensNet201_part3.h5
# Epoch 28/35
# 930/930 [==============================] - 975s 1s/step - loss: 0.1055 - acc: 0.9988 - auc: 0.9981 - f1: 0.9989 - val_loss: 0.0984 - val_acc: 1.0000 - val_auc: 0.9982 - val_f1: 1.0000
#
# Epoch 00028: val_auc improved from 0.99810 to 0.99818, saving model to DensNet201_part3.h5
# Epoch 29/35
# 930/930 [==============================] - 977s 1s/step - loss: 0.0982 - acc: 0.9997 - auc: 0.9982 - f1: 0.9998 - val_loss: 0.0969 - val_acc: 1.0000 - val_auc: 0.9983 - val_f1: 1.0000
#
# Epoch 00029: val_auc improved from 0.99818 to 0.99829, saving model to DensNet201_part3.h5
# Epoch 30/35
# 930/930 [==============================] - 982s 1s/step - loss: 0.0967 - acc: 0.9999 - auc: 0.9983 - f1: 0.9998 - val_loss: 0.0954 - val_acc: 1.0000 - val_auc: 0.9984 - val_f1: 1.0000
#
# Epoch 00030: val_auc improved from 0.99829 to 0.99838, saving model to DensNet201_part3.h5
# Epoch 31/35
# 930/930 [==============================] - 976s 1s/step - loss: 0.0974 - acc: 0.9994 - auc: 0.9984 - f1: 0.9995 - val_loss: 0.0943 - val_acc: 1.0000 - val_auc: 0.9985 - val_f1: 1.0000
#
# Epoch 00031: val_auc improved from 0.99838 to 0.99846, saving model to DensNet201_part3.h5
# Epoch 32/35
# 930/930 [==============================] - 975s 1s/step - loss: 0.0945 - acc: 0.9999 - auc: 0.9985 - f1: 0.9999 - val_loss: 0.0938 - val_acc: 1.0000 - val_auc: 0.9985 - val_f1: 1.0000
#
# Epoch 00032: val_auc improved from 0.99846 to 0.99854, saving model to DensNet201_part3.h5
# Epoch 33/35
# 930/930 [==============================] - 979s 1s/step - loss: 0.0939 - acc: 0.9997 - auc: 0.9986 - f1: 0.9998 - val_loss: 0.0929 - val_acc: 1.0000 - val_auc: 0.9986 - val_f1: 1.0000
#
# Epoch 00033: val_auc improved from 0.99854 to 0.99861, saving model to DensNet201_part3.h5
# Epoch 34/35
# 930/930 [==============================] - 981s 1s/step - loss: 0.0935 - acc: 0.9996 - auc: 0.9986 - f1: 0.9996 - val_loss: 0.0923 - val_acc: 1.0000 - val_auc: 0.9987 - val_f1: 1.0000
#
# Epoch 00034: val_auc improved from 0.99861 to 0.99868, saving model to DensNet201_part3.h5
# Epoch 35/35
# 930/930 [==============================] - 981s 1s/step - loss: 0.0924 - acc: 0.9999 - auc: 0.9987 - f1: 0.9999 - val_loss: 0.0915 - val_acc: 1.0000 - val_auc: 0.9987 - val_f1: 1.0000
#
# Epoch 00035: val_auc improved from 0.99868 to 0.99874, saving model to DensNet201_part3.h5

# %%
def show_loss(loss_history):
    epich = np.cumsum(np.concatenate(
        [np.linspace(0.5, 1, len(mh.epoch)) for mh in loss_history]))
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=(22, 10))
    _ = ax1.plot(epich,
                 np.concatenate([mh.history['loss'] for mh in loss_history]),
                 'b-',
                 epich, np.concatenate(
            [mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')

    _ = ax2.plot(epich, np.concatenate(
        [mh.history['acc'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_acc'] for mh in loss_history]),
                     'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('accuracy')
    
    _ = ax3.plot(epich, np.concatenate(
        [mh.history['auc'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_auc'] for mh in loss_history]),
                     'r-')
    ax3.legend(['Training', 'Validation'])
    ax3.set_title('auc')

    _ = ax4.plot(epich, np.concatenate(
        [mh.history['f1'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_f1'] for mh in loss_history]),
                     'r-')
    ax4.legend(['Training', 'Validation'])
    ax4.set_title('f1')
    
show_loss(loss_history)

# %%
# !pip install -U -q PyDrive

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a file.
uploaded = drive.CreateFile({'title': 'DensNet201_part3.h5'})
uploaded.SetContentFile('DensNet201_part3.h5')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1IocnwC4UkeyvViiRtBu_9PvSSebJCdVK

# %% [markdown]
# # Tune model

# %%
from keras.optimizers import Adam
from sklearn.metrics import roc_curve, auc, roc_auc_score
from keras.models import Model

from keras import backend as K
import tensorflow as tf
def auc(y_true, y_pred):
    auc = tf.metrics.auc(y_true, y_pred)[1]
    K.get_session().run(tf.local_variables_initializer())
    return auc
  
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

from keras.models import load_model
model_final = load_model('DensNet201_part5.h5', custom_objects = {'auc':auc, 'f1':f1})

# compile the model 
# model_final.compile(loss = "binary_crossentropy", optimizer = Adam(lr=0.00001, decay=0.00001), metrics=['accuracy',auc,f1])
# Out:
# WARNING:tensorflow:Variable *= will be deprecated. Use `var.assign(var * other)` if you want assignment to the variable value or `x = x * y` if you want a new python Tensor object.

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from google.colab import files

weight_path='DensNet201_part5_tune.h5'

checkpoint = ModelCheckpoint(weight_path, monitor='val_auc', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only=False)

reduceLROnPlat = ReduceLROnPlateau(monitor='f1', factor=0.1, patience=3, 
                                   verbose=1, mode='max', min_lr=0.0000001)

def exp_decay(epoch):
  initial_lrate = 0.0001
  k = 0.1
  lrate = initial_lrate * np.exp(-k*epoch)
  return lrate
lrate = LearningRateScheduler(exp_decay)
  
# class SaveWeight(Callback):
#     def on_epoch_end(self, batch, logs={}):
#         files.download('ResNet101_weights.hdf5')
#         return

# save_weight = SaveWeight()

callbacks_list = [checkpoint, lrate]

# %%
loss_history = [model_final.fit_generator(train_gen, 
                             steps_per_epoch = 7400/BATCH_SIZE, 
                             epochs = 45,
                             validation_data = val_gen,
                             validation_steps = 1800/BATCH_SIZE,
                             callbacks = callbacks_list,
                             initial_epoch=36)]
# Out:
# Epoch 37/45
# 925/925 [==============================] - 1007s 1s/step - loss: 0.0856 - acc: 1.0000 - auc: 1.0000 - f1: 1.0000 - val_loss: 0.1044 - val_acc: 0.9983 - val_auc: 1.0000 - val_f1: 0.9990
#
# Epoch 00037: val_auc improved from -inf to 0.99996, saving model to DensNet201_part5_tune.h5
# Epoch 38/45
# 925/925 [==============================] - 944s 1s/step - loss: 0.0858 - acc: 0.9997 - auc: 0.9999 - f1: 0.9997 - val_loss: 0.1045 - val_acc: 0.9983 - val_auc: 0.9999 - val_f1: 0.9990
#
# Epoch 00038: val_auc did not improve from 0.99996
# Epoch 39/45
# 925/925 [==============================] - 943s 1s/step - loss: 0.0848 - acc: 1.0000 - auc: 0.9999 - f1: 1.0000 - val_loss: 0.1061 - val_acc: 0.9972 - val_auc: 0.9999 - val_f1: 0.9982
#
# Epoch 00039: val_auc did not improve from 0.99996
# Epoch 40/45
# 925/925 [==============================] - 944s 1s/step - loss: 0.0851 - acc: 0.9996 - auc: 0.9999 - f1: 0.9997 - val_loss: 0.1058 - val_acc: 0.9967 - val_auc: 0.9999 - val_f1: 0.9979
#
# Epoch 00040: val_auc did not improve from 0.99996
# Epoch 41/45
# 925/925 [==============================] - 942s 1s/step - loss: 0.0846 - acc: 0.9999 - auc: 0.9999 - f1: 0.9999 - val_loss: 0.1032 - val_acc: 0.9983 - val_auc: 0.9999 - val_f1: 0.9990
#
# Epoch 00041: val_auc did not improve from 0.99996
# Epoch 42/45
# 925/925 [==============================] - 942s 1s/step - loss: 0.0841 - acc: 0.9997 - auc: 0.9999 - f1: 0.9997 - val_loss: 0.1067 - val_acc: 0.9961 - val_auc: 0.9999 - val_f1: 0.9975
#
# Epoch 00042: val_auc did not improve from 0.99996
# Epoch 43/45
# 925/925 [==============================] - 943s 1s/step - loss: 0.0841 - acc: 0.9997 - auc: 0.9999 - f1: 0.9998 - val_loss: 0.1082 - val_acc: 0.9956 - val_auc: 0.9999 - val_f1: 0.9971
#
# Epoch 00043: val_auc did not improve from 0.99996
# Epoch 44/45
# 925/925 [==============================] - 942s 1s/step - loss: 0.0836 - acc: 0.9997 - auc: 0.9999 - f1: 0.9998 - val_loss: 0.1063 - val_acc: 0.9961 - val_auc: 0.9999 - val_f1: 0.9975
#
# Epoch 00044: val_auc did not improve from 0.99996
# Epoch 45/45
# 925/925 [==============================] - 944s 1s/step - loss: 0.0831 - acc: 1.0000 - auc: 0.9999 - f1: 1.0000 - val_loss: 0.1027 - val_acc: 0.9983 - val_auc: 0.9999 - val_f1: 0.9990
#
# Epoch 00045: val_auc did not improve from 0.99996

# %%
# !pip install -U -q PyDrive

# %%
model_final.save('DensNet201_part5_tune')

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a file.
uploaded = drive.CreateFile({'title': 'DensNet201_part5_tune.h5'})
uploaded.SetContentFile('DensNet201_part5_tune.h5')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1-82xRiQCGyzIeO4krbPtxvRde-s4fo-b

# %% [markdown]
# # TEST

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.25.0)

# %%
from tqdm import tqdm
pred = []
for img in tqdm(test_filelist):
  image = imread(img)
  image = resize(image, (img_rows, img_cols, 3))
  crop_image = image # get_crop(image, img_rows)
  pred.append(model_final.predict(crop_image.reshape((1,crop_image.shape[0],crop_image.shape[1],crop_image.shape[2])))[0][0])
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
#   7%|▋         | 737/10000 [01:46<22:21,  6.90it/s]

# %%
test.drop(columns=[0,2], inplace=True)

# %%
test['path'] = [*map(lambda x: x.split('/')[2], test_filelist)]
test['pred'] = pred
test.columns = [0,2]

test.to_csv('predictsDenseNet201_part5.csv', index=False)
test.head()
# Out:
#               0         2
# 0  3A62AJNZ.png  0.038418
# 1  0BZ6729J.png  0.038880
# 2  70R0U71A.png  0.000069
# 3  3RPTDT8M.png  0.007385
# 4  SK6LMUQP.png  0.003364

# %%
files.download('predictsDenseNet201_part3.csv')
